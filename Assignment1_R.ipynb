# %%
csv_data<-read.csv("regrex1.csv")
print(csv_data)
# Out:
#          y       x
# 1   6.8102  9.8492
# 2   9.8437 11.1450
# 3   4.9767  5.1209
# 4   5.0006  8.1085
# 5   3.5047  3.5599
# 6   3.6419  1.9883
# 7   7.8725 15.5322
# 8   5.1442  7.5202
# 9   8.3883 14.0202
# 10  6.8204  7.5226
# 11  9.0185 14.3272
# 12  2.6148  3.8950
# 13  3.7367  1.8707
# 14  2.8651  0.8347
# 15 10.7469 18.3413
# 16  2.3710  1.6645
# 17  9.6653 17.0579
# 18  7.1926  9.2375
# 19 11.7833 21.0000
# 20  3.9537  3.5286
# 21 15.0000 25.0000
# 22  7.9152  9.9008
# 23  9.3368 17.5990
# 24  8.7587 13.8790
# 25  6.7813 10.8690
# 26  7.9924 12.6238
# 27  2.2806  0.9719
# 28 10.4050 14.4814
# 29  3.7891  2.1792
# 30 10.9067 18.4052

# %%
plot(x = csv_data$x,
     y = csv_data$y,
     xlab = "x",
     ylab = "y",
     col = "black",
     pch = 4,
     main = "regrex1")
# Out:
# Plot with title “regrex1”

# %%
plot(x = csv_data$x,
     y = csv_data$y,
     xlab = "x",
     ylab = "y",
     col = "black",
     pch = 4,
     main = "Regrex Data")

abline(lm(csv_data$y ~ csv_data$x,
          data = csv_data), col = "black")
# Out:
# Plot with title “Regrex Data”
